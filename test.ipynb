# %%
import pandas as pd 
df = pd.read_csv("rentfaster.csv") 
print("(# of Rows, # of Columns):", df.shape) 
print("\nTypes: \n", df.dtypes) # types: object, float64, int64 
print("\nNumber of values missing per column:\n ", df.isnull().sum()) # missing per column 
df.head()
# Out:
# (# of Rows, # of Columns): (25771, 18)
#
# Types:
#  rentfaster_id          int64
# city                  object
# province              object
# address               object
# latitude             float64
# longitude            float64
# lease_term            object
# type                  object
# price                float64
# beds                  object
# baths                 object
# sq_feet               object
# link                  object
# furnishing            object
# availability_date     object
# smoking               object
# cats                  object
# dogs                  object
# dtype: object
#
# Number of values missing per column:
#   rentfaster_id           0
# city                    0
# province                0
# address               125
# latitude                0
# longitude               0
# lease_term             46
# type                    0
# price                   0
# beds                  132
# baths                 134
# ...

# %%
filtered_df = df[df['province'].isin(['Alberta', 'British Columbia', 'Ontario'])]
print("# of rows for Alberta, BC, and Ontario: ", filtered_df.shape[0])
# Out:
# # of rows for Alberta, BC, and Ontario:  21558
